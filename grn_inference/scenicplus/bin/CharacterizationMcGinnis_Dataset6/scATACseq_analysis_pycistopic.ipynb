# %% [markdown]
# # scATAC-seq analysis

# %% [markdown]
# Set-up for running a scATAC-seq analysis with pycisTopic.

# %%
import os
import sys
import glob
import warnings
import pandas as pd
import pycisTopic
import pyranges as pr
import requests
warnings.simplefilter(action='ignore', category=FutureWarning)
_stderr = sys.stderr
null = open(os.devnull,'wb')

# %%
dataset_name = "CharacterizationMcGinnis_Dataset6"
combinomics_dir = "/cellar/users/aklie/data/igvf/topic_grn_links/combinomics"
results_dir = "/cellar/users/aklie/projects/igvf/topic_grn_links/grn_inference/scenicplus/results"
dataset_name = "CharacterizationMcGinnis_Dataset6"

# %%
#make a directory for to store the processed scATAC-seq data.
if not os.path.exists(os.path.join(results_dir, dataset_name, 'scATAC')):
    os.makedirs(os.path.join(results_dir, dataset_name, 'scATAC'))
tmp_dir = '/cellar/users/aklie/tmp/'

# %% [markdown]
# You will need to create a dictionary with values as paths to fragment files and keys as sample names.

# %%
fragment_files = os.path.join(combinomics_dir, dataset_name, "*tsv.gz")
fragment_files = sorted(glob.glob(fragment_files))
fragment_files
# Out:
# ['/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_1.atac.filter.fragments.hg38.tsv.gz',
#  '/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_2.atac.filter.fragments.hg38.tsv.gz',
#  '/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_3.atac.filter.fragments.hg38.tsv.gz',
#  '/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_4.atac.filter.fragments.hg38.tsv.gz']

# %%
# Load in the paths to your fragment files and turn them into a dictionary
fragments_dict = dict(zip([os.path.basename(file).split(".")[0] for file in fragment_files], fragment_files))
fragments_dict
# Out:
# {'Dataset6_sample_1': '/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_1.atac.filter.fragments.hg38.tsv.gz',
#  'Dataset6_sample_2': '/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_2.atac.filter.fragments.hg38.tsv.gz',
#  'Dataset6_sample_3': '/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_3.atac.filter.fragments.hg38.tsv.gz',
#  'Dataset6_sample_4': '/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_4.atac.filter.fragments.hg38.tsv.gz'}

# %% [markdown]
# Read in or grab the metadata from any previous methods for annotations

# %%
atac_metadata_glob = os.path.join(combinomics_dir, dataset_name, '*atac.qc.hg38.metadata.tsv')
atac_metadata_files = sorted(glob.glob(atac_metadata_glob))
atac_metadata_files
# Out:
# ['/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_1.atac.qc.hg38.metadata.tsv',
#  '/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_2.atac.qc.hg38.metadata.tsv',
#  '/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_3.atac.qc.hg38.metadata.tsv',
#  '/cellar/users/aklie/data/igvf/topic_grn_links/combinomics/CharacterizationMcGinnis_Dataset6/Dataset6_sample_4.atac.qc.hg38.metadata.tsv']

# %%
metadata = pd.concat([pd.read_csv(f, sep='\t', index_col=0) for f in atac_metadata_files])

# %%
# Chris McGinnis annotations
metadata_dir = "/cellar/users/aklie/data/igvf/topic_grn_links/metadata"
processed_metadata_file = os.path.join(metadata_dir, dataset_name, 'metadata_IGVF6.csv')
processed_metadata = pd.read_csv(processed_metadata_file, index_col=0)
index_split = processed_metadata.index.str.split("-")
processed_metadata.index = [x[0] + "_Dataset6_sample_" + x[1] for x in index_split]
processed_metadata
# Out:
#                                        orig.ident  nCount_RNA  nFeature_RNA  \
# AAACAGCCAAGGTAAC_Dataset6_sample_1  SeuratProject        5710          2647
# AAACAGCCACCTCGCT_Dataset6_sample_1  SeuratProject        7103          2723
# AAACAGCCACTCGCTC_Dataset6_sample_1  SeuratProject        6402          2918
# AAACAGCCAGCAATAA_Dataset6_sample_1  SeuratProject        1721           991
# AAACAGCCAGCGCTTG_Dataset6_sample_1  SeuratProject        2853          1535
# ...                                           ...         ...           ...
# TTTGTTGGTGTCCAAA_Dataset6_sample_4  SeuratProject        5090          2357
# TTTGTTGGTGTCCTGC_Dataset6_sample_4  SeuratProject        3570          1924
# TTTGTTGGTGTTTGTC_Dataset6_sample_4  SeuratProject        1093           890
# TTTGTTGGTTAAGCGC_Dataset6_sample_4  SeuratProject        5066          2621
# TTTGTTGGTTGGCCGA_Dataset6_sample_4  SeuratProject        2989          1863
#
#                                     RNA_snn_res.0.25  seurat_clusters  \
# AAACAGCCAAGGTAAC_Dataset6_sample_1                10                9
# AAACAGCCACCTCGCT_Dataset6_sample_1                13               21
# AAACAGCCACTCGCTC_Dataset6_sample_1                 3                2
# AAACAGCCAGCAATAA_Dataset6_sample_1                 7                3
# AAACAGCCAGCGCTTG_Dataset6_sample_1                 5               15
# ...                                              ...              ...
# TTTGTTGGTGTCCAAA_Dataset6_sample_4                 2                0
# TTTGTTGGTGTCCTGC_Dataset6_sample_4                 6                6
# TTTGTTGGTGTTTGTC_Dataset6_sample_4                 0                7
# TTTGTTGGTTAAGCGC_Dataset6_sample_4                10               24
# TTTGTTGGTTGGCCGA_Dataset6_sample_4                 9                8
#
#                                     PercentMito  lane  MULTI  RNA_snn_res.1  \
# AAACAGCCAAGGTAAC_Dataset6_sample_1     0.066900     1  Bar64              9
# AAACAGCCACCTCGCT_Dataset6_sample_1     0.059693     1  Bar63             21
# AAACAGCCACTCGCTC_Dataset6_sample_1     0.037176     1  Bar64              2
# AAACAGCCAGCAATAA_Dataset6_sample_1     0.160372     1  Bar65              3
# AAACAGCCAGCGCTTG_Dataset6_sample_1     0.049772     1  Bar66             15
# ...                                         ...   ...    ...            ...
# TTTGTTGGTGTCCAAA_Dataset6_sample_4     0.038310     4  Bar66              0
# TTTGTTGGTGTCCTGC_Dataset6_sample_4     0.001681     4  Bar64              6
# TTTGTTGGTGTTTGTC_Dataset6_sample_4     0.020128     4  Bar63              7
# TTTGTTGGTTAAGCGC_Dataset6_sample_4     0.042835     4  Bar65             24
# TTTGTTGGTTGGCCGA_Dataset6_sample_4     0.055872     4  Bar61              8
#
#                                     RNA_snn_res.0.5   sample  temp
# AAACAGCCAAGGTAAC_Dataset6_sample_1                8    S5_2D     9
# AAACAGCCACCTCGCT_Dataset6_sample_1               13       S4    21
# AAACAGCCACTCGCTC_Dataset6_sample_1                4    S5_2D     2
# AAACAGCCAGCAATAA_Dataset6_sample_1                6  S5_2D3D     3
# AAACAGCCAGCGCTTG_Dataset6_sample_1                2    S6_2D    15
# ...                                             ...      ...   ...
# TTTGTTGGTGTCCAAA_Dataset6_sample_4                1    S6_2D     0
# TTTGTTGGTGTCCTGC_Dataset6_sample_4                5    S5_2D     6
# TTTGTTGGTGTTTGTC_Dataset6_sample_4               10       S4     7
# TTTGTTGGTTAAGCGC_Dataset6_sample_4                8  S5_2D3D    24
# TTTGTTGGTTGGCCGA_Dataset6_sample_4                9       S1     8
#
# [72152 rows x 12 columns]

# %%
metadata.merge(processed_metadata, left_index=True, right_index=True, how="inner")
# Out:
#                                     fragments_promoter  reads_tss  \
# AAACAGCCAAACGCGA_Dataset6_sample_4               17088       3423
# AAACAGCCAACCTAAT_Dataset6_sample_3               28363       6324
# AAACAGCCAACGTGCT_Dataset6_sample_2                1989        370
# AAACAGCCAACTGGCT_Dataset6_sample_2               20899       4449
# AAACAGCCAAGCCAGA_Dataset6_sample_4               42589       9141
# ...                                                ...        ...
# TTTGTTGGTTGGCCGA_Dataset6_sample_4               68800      13642
# TTTGTTGGTTTAACGG_Dataset6_sample_1               90339      18836
# TTTGTTGGTTTATTCG_Dataset6_sample_3               39529       9556
# TTTGTTGGTTTGCAGA_Dataset6_sample_2               27188       5644
# TTTGTTGGTTTGGCTT_Dataset6_sample_3               66185      13965
#
#                                     reads_promoter  tss_enrichment  \
# AAACAGCCAAACGCGA_Dataset6_sample_4           33940       14.033577
# AAACAGCCAACCTAAT_Dataset6_sample_3           56294       14.527578
# AAACAGCCAACGTGCT_Dataset6_sample_2            3937       11.817311
# AAACAGCCAACTGGCT_Dataset6_sample_2           41451       14.141093
# AAACAGCCAAGCCAGA_Dataset6_sample_4           84417       15.021569
# ...                                            ...             ...
# TTTGTTGGTTGGCCGA_Dataset6_sample_4          136343       12.724381
# TTTGTTGGTTTAACGG_Dataset6_sample_1          179149       15.021752
# TTTGTTGGTTTATTCG_Dataset6_sample_3           78510       21.901357
# TTTGTTGGTTTGCAGA_Dataset6_sample_2           53924       16.484126
# TTTGTTGGTTTGGCTT_Dataset6_sample_3          131104       15.278158
#
#                                     reads_tss_total  total  duplicate  \
# AAACAGCCAAACGCGA_Dataset6_sample_4           3423.0  10210       2872
# AAACAGCCAACCTAAT_Dataset6_sample_3           6324.0  14754       4991
# AAACAGCCAACGTGCT_Dataset6_sample_2            370.0   1280        341
# AAACAGCCAACTGGCT_Dataset6_sample_2           4449.0  10961       3392
# AAACAGCCAAGCCAGA_Dataset6_sample_4           9141.0  21966       6166
# ...                                             ...    ...        ...
# TTTGTTGGTTGGCCGA_Dataset6_sample_4          13642.0  37133       9709
# TTTGTTGGTTTAACGG_Dataset6_sample_1          18836.0  63967      24015
# TTTGTTGGTTTATTCG_Dataset6_sample_3           9556.0  21712       6899
# TTTGTTGGTTTGCAGA_Dataset6_sample_2           5644.0  14667       4342
# TTTGTTGGTTTGGCTT_Dataset6_sample_3          13965.0  40163      12525
#
#                                     unmapped  lowmapq  unique  ...  \
# AAACAGCCAAACGCGA_Dataset6_sample_4       754        0    6584  ...
# AAACAGCCAACCTAAT_Dataset6_sample_3       830        0    8933  ...
# AAACAGCCAACGTGCT_Dataset6_sample_2       121        0     818  ...
# AAACAGCCAACTGGCT_Dataset6_sample_2       581        0    6988  ...
# AAACAGCCAAGCCAGA_Dataset6_sample_4      1153        0   14647  ...
# ...                                      ...      ...     ...  ...
# TTTGTTGGTTGGCCGA_Dataset6_sample_4      3032        0   24392  ...
# TTTGTTGGTTTAACGG_Dataset6_sample_1      3805        0   36147  ...
# TTTGTTGGTTTATTCG_Dataset6_sample_3      1339        0   13474  ...
# TTTGTTGGTTTGCAGA_Dataset6_sample_2       905        0    9420  ...
# TTTGTTGGTTTGGCTT_Dataset6_sample_3      2308        0   25330  ...
#
#                                     nFeature_RNA  RNA_snn_res.0.25  \
# AAACAGCCAAACGCGA_Dataset6_sample_4           457                 7
# AAACAGCCAACCTAAT_Dataset6_sample_3          2503                 1
# AAACAGCCAACGTGCT_Dataset6_sample_2          4350                11
# AAACAGCCAACTGGCT_Dataset6_sample_2          2168                 1
# AAACAGCCAAGCCAGA_Dataset6_sample_4          3478                 1
# ...                                          ...               ...
# TTTGTTGGTTGGCCGA_Dataset6_sample_4          1863                 9
# TTTGTTGGTTTAACGG_Dataset6_sample_1          1505                 8
# TTTGTTGGTTTATTCG_Dataset6_sample_3          1681                 4
# TTTGTTGGTTTGCAGA_Dataset6_sample_2          1046                 0
# TTTGTTGGTTTGGCTT_Dataset6_sample_3          1253                 5
#
#                                     seurat_clusters  PercentMito  lane  MULTI  \
# AAACAGCCAAACGCGA_Dataset6_sample_4               23     0.187793     4  Bar63
# AAACAGCCAACCTAAT_Dataset6_sample_3               12     0.082565     3  Bar66
# AAACAGCCAACGTGCT_Dataset6_sample_2               25     0.083430     2  Bar63
# AAACAGCCAACTGGCT_Dataset6_sample_2                1     0.061338     2  Bar66
# AAACAGCCAAGCCAGA_Dataset6_sample_4               12     0.054582     4  Bar66
# ...                                             ...          ...   ...    ...
# TTTGTTGGTTGGCCGA_Dataset6_sample_4                8     0.055872     4  Bar61
# TTTGTTGGTTTAACGG_Dataset6_sample_1               20     0.006016     1  Bar63
# TTTGTTGGTTTATTCG_Dataset6_sample_3                4     0.047019     3  Bar64
# TTTGTTGGTTTGCAGA_Dataset6_sample_2                7     0.034535     2  Bar63
# TTTGTTGGTTTGGCTT_Dataset6_sample_3               15     0.157895     3  Bar67
#
#                                     RNA_snn_res.1 RNA_snn_res.0.5   sample  \
# AAACAGCCAAACGCGA_Dataset6_sample_4             23              12       S4
# AAACAGCCAACCTAAT_Dataset6_sample_3             12               0    S6_2D
# AAACAGCCAACGTGCT_Dataset6_sample_2             25              16       S4
# AAACAGCCAACTGGCT_Dataset6_sample_2              1               0    S6_2D
# AAACAGCCAAGCCAGA_Dataset6_sample_4             12               0    S6_2D
# ...                                           ...             ...      ...
# TTTGTTGGTTGGCCGA_Dataset6_sample_4              8               9       S1
# TTTGTTGGTTTAACGG_Dataset6_sample_1             20               7       S4
# TTTGTTGGTTTATTCG_Dataset6_sample_3              4               3    S5_2D
# TTTGTTGGTTTGCAGA_Dataset6_sample_2              7              10       S4
# TTTGTTGGTTTGGCTT_Dataset6_sample_3             15               2  S6_2D3D
#
#                                     temp
# AAACAGCCAAACGCGA_Dataset6_sample_4    23
# AAACAGCCAACCTAAT_Dataset6_sample_3    12
# AAACAGCCAACGTGCT_Dataset6_sample_2    25
# AAACAGCCAACTGGCT_Dataset6_sample_2     1
# AAACAGCCAAGCCAGA_Dataset6_sample_4    12
# ...                                  ...
# TTTGTTGGTTGGCCGA_Dataset6_sample_4     8
# TTTGTTGGTTTAACGG_Dataset6_sample_1    20
# TTTGTTGGTTTATTCG_Dataset6_sample_3     4
# TTTGTTGGTTTGCAGA_Dataset6_sample_2     7
# TTTGTTGGTTTGGCTT_Dataset6_sample_3    15
#
# [72104 rows x 29 columns]

# %%
processed_metadata
# Out:
#                                        orig.ident  nCount_RNA  nFeature_RNA  \
# AAACAGCCAAGGTAAC_Dataset6_sample_1  SeuratProject        5710          2647
# AAACAGCCACCTCGCT_Dataset6_sample_1  SeuratProject        7103          2723
# AAACAGCCACTCGCTC_Dataset6_sample_1  SeuratProject        6402          2918
# AAACAGCCAGCAATAA_Dataset6_sample_1  SeuratProject        1721           991
# AAACAGCCAGCGCTTG_Dataset6_sample_1  SeuratProject        2853          1535
# ...                                           ...         ...           ...
# TTTGTTGGTGTCCAAA_Dataset6_sample_4  SeuratProject        5090          2357
# TTTGTTGGTGTCCTGC_Dataset6_sample_4  SeuratProject        3570          1924
# TTTGTTGGTGTTTGTC_Dataset6_sample_4  SeuratProject        1093           890
# TTTGTTGGTTAAGCGC_Dataset6_sample_4  SeuratProject        5066          2621
# TTTGTTGGTTGGCCGA_Dataset6_sample_4  SeuratProject        2989          1863
#
#                                     RNA_snn_res.0.25  seurat_clusters  \
# AAACAGCCAAGGTAAC_Dataset6_sample_1                10                9
# AAACAGCCACCTCGCT_Dataset6_sample_1                13               21
# AAACAGCCACTCGCTC_Dataset6_sample_1                 3                2
# AAACAGCCAGCAATAA_Dataset6_sample_1                 7                3
# AAACAGCCAGCGCTTG_Dataset6_sample_1                 5               15
# ...                                              ...              ...
# TTTGTTGGTGTCCAAA_Dataset6_sample_4                 2                0
# TTTGTTGGTGTCCTGC_Dataset6_sample_4                 6                6
# TTTGTTGGTGTTTGTC_Dataset6_sample_4                 0                7
# TTTGTTGGTTAAGCGC_Dataset6_sample_4                10               24
# TTTGTTGGTTGGCCGA_Dataset6_sample_4                 9                8
#
#                                     PercentMito  lane  MULTI  RNA_snn_res.1  \
# AAACAGCCAAGGTAAC_Dataset6_sample_1     0.066900     1  Bar64              9
# AAACAGCCACCTCGCT_Dataset6_sample_1     0.059693     1  Bar63             21
# AAACAGCCACTCGCTC_Dataset6_sample_1     0.037176     1  Bar64              2
# AAACAGCCAGCAATAA_Dataset6_sample_1     0.160372     1  Bar65              3
# AAACAGCCAGCGCTTG_Dataset6_sample_1     0.049772     1  Bar66             15
# ...                                         ...   ...    ...            ...
# TTTGTTGGTGTCCAAA_Dataset6_sample_4     0.038310     4  Bar66              0
# TTTGTTGGTGTCCTGC_Dataset6_sample_4     0.001681     4  Bar64              6
# TTTGTTGGTGTTTGTC_Dataset6_sample_4     0.020128     4  Bar63              7
# TTTGTTGGTTAAGCGC_Dataset6_sample_4     0.042835     4  Bar65             24
# TTTGTTGGTTGGCCGA_Dataset6_sample_4     0.055872     4  Bar61              8
#
#                                     RNA_snn_res.0.5   sample  temp
# AAACAGCCAAGGTAAC_Dataset6_sample_1                8    S5_2D     9
# AAACAGCCACCTCGCT_Dataset6_sample_1               13       S4    21
# AAACAGCCACTCGCTC_Dataset6_sample_1                4    S5_2D     2
# AAACAGCCAGCAATAA_Dataset6_sample_1                6  S5_2D3D     3
# AAACAGCCAGCGCTTG_Dataset6_sample_1                2    S6_2D    15
# ...                                             ...      ...   ...
# TTTGTTGGTGTCCAAA_Dataset6_sample_4                1    S6_2D     0
# TTTGTTGGTGTCCTGC_Dataset6_sample_4                5    S5_2D     6
# TTTGTTGGTGTTTGTC_Dataset6_sample_4               10       S4     7
# TTTGTTGGTTAAGCGC_Dataset6_sample_4                8  S5_2D3D    24
# TTTGTTGGTTGGCCGA_Dataset6_sample_4                9       S1     8
#
# [72152 rows x 12 columns]

# %% [markdown]
# Map the RNA barcodes from the anndata to the ATAC barcodes present in the fragment file

# %%
test_fragments = pd.read_csv(fragments_dict["Dataset6_sample_4"], sep="\t", header=None, nrows=1000)
metadata.index.isin(test_fragments[3]).sum()

# %% [markdown]
# We also need chromosome sizes in order to export to pseudobulk and to call peaks. Read these in. Make sure you choose the correct species for your data!

# %%
# Stream directly into memory using pandas
target_url = 'http://hgdownload.cse.ucsc.edu/goldenPath/hg38/bigZips/hg38.chrom.sizes'
chromsizes = pd.read_csv(target_url, sep='\t', header=None)
chromsizes.columns = ['Chromosome', 'End']
chromsizes['Start'] = [0]*chromsizes.shape[0]
chromsizes = chromsizes.loc[:,['Chromosome', 'Start', 'End']]
chromsizes = pr.PyRanges(chromsizes)

# %%
chromsizes
# Out:
# +------------------------+-----------+-----------+
# | Chromosome             | Start     | End       |
# | (category)             | (int32)   | (int32)   |
# |------------------------+-----------+-----------|
# | chr1                   | 0         | 248956422 |
# | chr1_GL383518v1_alt    | 0         | 182439    |
# | chr1_GL383519v1_alt    | 0         | 110268    |
# | chr1_GL383520v2_alt    | 0         | 366580    |
# | ...                    | ...       | ...       |
# | chrX_KI270881v1_alt    | 0         | 144206    |
# | chrX_KI270913v1_alt    | 0         | 274009    |
# | chrY                   | 0         | 57227415  |
# | chrY_KI270740v1_random | 0         | 37240     |
# +------------------------+-----------+-----------+
# Unstranded PyRanges object has 455 rows and 3 columns from 455 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.

# %% [markdown]
# The next big step is to generate bed and bw files using all the fragments within each cell type. pycisTopic has a decent function for this that's a little finicky. A couple things to make sure of:
# - You have a "barcode" column with barcodes that match the barcodes in your fragment files
# - You have a "sample_id" column that maps cells to the samples contained in your fragment file dictionary
# - Your chromosomes in the chromsizes object you created match the chromsomes in your fragment files (make sure you have the right species)
# - You have enough total memory to handle ray's parallelization (if you use it)

# %%
metadata
# Out:
#                                     fragments_promoter  reads_tss  \
# barcode
# AAACAGCCAAACCTTG_Dataset6_sample_1                 939        132
# AAACAGCCAAACGCGA_Dataset6_sample_1                  28          4
# AAACAGCCAAACGGGC_Dataset6_sample_1                 105         20
# AAACAGCCAAAGCGCA_Dataset6_sample_1                  29          1
# AAACAGCCAAAGCTAA_Dataset6_sample_1                  43          4
# ...                                                ...        ...
# TTTGTTGGTTTGCAGA_Dataset6_sample_4                  67         13
# TTTGTTGGTTTGGCTT_Dataset6_sample_4                  99          4
# TTTGTTGGTTTGGGCG_Dataset6_sample_4                  32         17
# TTTGTTGGTTTGGGTA_Dataset6_sample_4                  19         10
# TTTGTTGGTTTGTCTA_Dataset6_sample_4                 401         64
#
#                                     reads_promoter  tss_enrichment  \
# barcode
# AAACAGCCAAACCTTG_Dataset6_sample_1            1849        3.308685
# AAACAGCCAAACGCGA_Dataset6_sample_1              56        0.396040
# AAACAGCCAAACGGGC_Dataset6_sample_1             210        1.980198
# AAACAGCCAAAGCGCA_Dataset6_sample_1              57        0.099010
# AAACAGCCAAAGCTAA_Dataset6_sample_1              83        0.396040
# ...                                            ...             ...
# TTTGTTGGTTTGCAGA_Dataset6_sample_4             132        1.287129
# TTTGTTGGTTTGGCTT_Dataset6_sample_4             196        0.396040
# TTTGTTGGTTTGGGCG_Dataset6_sample_4              63        1.683168
# TTTGTTGGTTTGGGTA_Dataset6_sample_4              38        0.990099
# TTTGTTGGTTTGTCTA_Dataset6_sample_4             797        6.336634
#
#                                     reads_tss_total  total  duplicate  \
# barcode
# AAACAGCCAAACCTTG_Dataset6_sample_1            132.0   1366        440
# AAACAGCCAAACGCGA_Dataset6_sample_1              4.0     31          4
# AAACAGCCAAACGGGC_Dataset6_sample_1             20.0     60          4
# AAACAGCCAAAGCGCA_Dataset6_sample_1              1.0     20          8
# AAACAGCCAAAGCTAA_Dataset6_sample_1              4.0     41         13
# ...                                             ...    ...        ...
# TTTGTTGGTTTGCAGA_Dataset6_sample_4             13.0     23          0
# TTTGTTGGTTTGGCTT_Dataset6_sample_4              4.0     59          1
# TTTGTTGGTTTGGGCG_Dataset6_sample_4             17.0     25          3
# TTTGTTGGTTTGGGTA_Dataset6_sample_4             10.0     16          2
# TTTGTTGGTTTGTCTA_Dataset6_sample_4             64.0    399         97
#
#                                     unmapped  lowmapq  unique   pct_dup  \
# barcode
# AAACAGCCAAACCTTG_Dataset6_sample_1       218        0     708  0.383275
# AAACAGCCAAACGCGA_Dataset6_sample_1         3        0      24  0.142857
# AAACAGCCAAACGGGC_Dataset6_sample_1         5        0      51  0.072727
# AAACAGCCAAAGCGCA_Dataset6_sample_1         1        0      11  0.421053
# AAACAGCCAAAGCTAA_Dataset6_sample_1         7        0      21  0.382353
# ...                                      ...      ...     ...       ...
# TTTGTTGGTTTGCAGA_Dataset6_sample_4         5        0      18  0.000000
# TTTGTTGGTTTGGCTT_Dataset6_sample_4        13        0      45  0.021739
# TTTGTTGGTTTGGGCG_Dataset6_sample_4         5        0      17  0.150000
# TTTGTTGGTTTGGGTA_Dataset6_sample_4         1        0      13  0.133333
# TTTGTTGGTTTGTCTA_Dataset6_sample_4        44        0     258  0.273239
#
#                                     pct_unmapped  reads_peaks  fragment_peaks  \
# barcode
# AAACAGCCAAACCTTG_Dataset6_sample_1      0.159590          290             187
# AAACAGCCAAACGCGA_Dataset6_sample_1      0.096774           16              11
# AAACAGCCAAACGGGC_Dataset6_sample_1      0.083333           40              23
# AAACAGCCAAAGCGCA_Dataset6_sample_1      0.050000            2               1
# AAACAGCCAAAGCTAA_Dataset6_sample_1      0.170732           28              18
# ...                                          ...          ...             ...
# TTTGTTGGTTTGCAGA_Dataset6_sample_4      0.217391           10               6
# TTTGTTGGTTTGGCTT_Dataset6_sample_4      0.220339           33              23
# TTTGTTGGTTTGGGCG_Dataset6_sample_4      0.200000            8               6
# TTTGTTGGTTTGGGTA_Dataset6_sample_4      0.062500           13               7
# TTTGTTGGTTTGTCTA_Dataset6_sample_4      0.110276           98              64
#
#                                     pct_reads_promoter  pct_reads_peaks  \
# barcode
# AAACAGCCAAACCTTG_Dataset6_sample_1             135.359                0
# AAACAGCCAAACGCGA_Dataset6_sample_1             180.645                0
# AAACAGCCAAACGGGC_Dataset6_sample_1             350.000                0
# AAACAGCCAAAGCGCA_Dataset6_sample_1             285.000                0
# AAACAGCCAAAGCTAA_Dataset6_sample_1             202.439                0
# ...                                                ...              ...
# TTTGTTGGTTTGCAGA_Dataset6_sample_4             573.913                0
# TTTGTTGGTTTGGCTT_Dataset6_sample_4             332.203                0
# TTTGTTGGTTTGGGCG_Dataset6_sample_4             252.000                0
# TTTGTTGGTTTGGGTA_Dataset6_sample_4             237.500                0
# TTTGTTGGTTTGTCTA_Dataset6_sample_4             199.749                0
#
#                                     pct_mito_reads
# barcode
# AAACAGCCAAACCTTG_Dataset6_sample_1         29.3977
# AAACAGCCAAACGCGA_Dataset6_sample_1         40.3846
# AAACAGCCAAACGGGC_Dataset6_sample_1         53.3980
# AAACAGCCAAAGCGCA_Dataset6_sample_1         10.6145
# AAACAGCCAAAGCTAA_Dataset6_sample_1         30.8690
# ...                                            ...
# TTTGTTGGTTTGCAGA_Dataset6_sample_4        100.0000
# TTTGTTGGTTTGGCTT_Dataset6_sample_4         91.0198
# TTTGTTGGTTTGGGCG_Dataset6_sample_4         57.1429
# TTTGTTGGTTTGGGTA_Dataset6_sample_4         31.9149
# TTTGTTGGTTTGTCTA_Dataset6_sample_4         28.7540
#
# [1239392 rows x 17 columns]

# %%
from pycisTopic.pseudobulk_peak_calling import export_pseudobulk

# Run without ray since these are big files
bw_paths, bed_paths = export_pseudobulk(
    input_data = cell_data,
    variable = 'celltype', # variable by which to generate pseubulk profiles, in this case we want pseudobulks per celltype
    sample_id_col = 'sample_id',
    chromsizes = chromsizes,
    bed_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bed_files/'),  # specify where pseudobulk_bed_files should be stored
    bigwig_path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bw_files/'), # specify where pseudobulk_bw_files should be stored
    path_to_fragments = fragments_dict, # location of fragment fiels
    n_cpu = 1, # specify the number of cores to use, we use ray for multi processing
    normalize_bigwig = True,
    remove_duplicates = True,
    _temp_dir = os.path.join(tmp_dir, 'ray_spill'),
    split_pattern = '-'
)
# Out:
# 2023-01-14 22:54:59,585 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF187VMN/encode_scatac_dcc_2/results/ENCSR525WPH-1/fragments/fragments.tsv.gz
# 2023-01-14 22:56:44,138 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF035SPT/encode_scatac_dcc_2/results/ENCSR713FPX-1/fragments/fragments.tsv.gz
# 2023-01-14 22:58:25,383 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF622EUO/encode_scatac_dcc_2/results/ENCSR858YSB-1/fragments/fragments.tsv.gz
# 2023-01-14 23:00:24,434 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF119IVK/encode_scatac_dcc_2/results/ENCSR400PXQ-1/fragments/fragments.tsv.gz
# 2023-01-14 23:01:55,753 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF683IBE/encode_scatac_dcc_2/results/ENCSR668VPD-1/fragments/fragments.tsv.gz
# 2023-01-14 23:03:56,191 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF042ZJI/encode_scatac_dcc_2/results/ENCSR736ABS-1/fragments/fragments.tsv.gz
# 2023-01-14 23:05:45,716 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF176LJV/encode_scatac_dcc_2/results/ENCSR834NRP-1/fragments/fragments.tsv.gz
# 2023-01-14 23:07:43,911 cisTopic     INFO     Reading fragments from /cellar/users/aklie/data/igvf/topic_grn_links/mouse_adrenal/encode/fragments/ENCFF101BLM/encode_scatac_dcc_2/results/ENCSR024LKR-1/fragments/fragments.tsv.gz
# 2023-01-14 23:09:27,214 cisTopic     INFO     Creating pseudobulk for Adipocytes
# 2023-01-14 23:13:44,808 cisTopic     INFO     Adipocytes done!
# 2023-01-14 23:13:44,992 cisTopic     INFO     Creating pseudobulk for Capsule
# 2023-01-14 23:13:57,686 cisTopic     INFO     Capsule done!
# 2023-01-14 23:13:57,695 cisTopic     INFO     Creating pseudobulk for Cortex
# 2023-01-15 00:59:03,988 cisTopic     INFO     Cortex done!
# 2023-01-15 00:59:08,161 cisTopic     INFO     Creating pseudobulk for Endothelial
# 2023-01-15 01:12:19,987 cisTopic     INFO     Endothelial done!
# 2023-01-15 01:12:20,496 cisTopic     INFO     Creating pseudobulk for Fibroblast
# 2023-01-15 01:14:54,515 cisTopic     INFO     Fibroblast done!
# 2023-01-15 01:14:54,575 cisTopic     INFO     Creating pseudobulk for Hepatocyte
# 2023-01-15 01:15:01,065 cisTopic     INFO     Hepatocyte done!
# 2023-01-15 01:15:01,067 cisTopic     INFO     Creating pseudobulk for Macrophages
# 2023-01-15 01:16:52,776 cisTopic     INFO     Macrophages done!
# 2023-01-15 01:16:52,819 cisTopic     INFO     Creating pseudobulk for Medulla
# 2023-01-15 01:27:23,012 cisTopic     INFO     Medulla done!
# 2023-01-15 01:27:23,200 cisTopic     INFO     Creating pseudobulk for Skeletal_muscle
# 2023-01-15 01:27:27,106 cisTopic     INFO     Skeletal_muscle done!
# 2023-01-15 01:27:27,107 cisTopic     INFO     Creating pseudobulk for Smooth_muscle
# 2023-01-15 01:27:40,009 cisTopic     INFO     Smooth_muscle done!
# 2023-01-15 01:27:40,015 cisTopic     INFO     Creating pseudobulk for Sox10_
# 2023-01-15 01:28:20,816 cisTopic     INFO     Sox10_ done!
# 2023-01-15 01:28:20,827 cisTopic     INFO     Creating pseudobulk for Stromal
# 2023-01-15 01:32:55,037 cisTopic     INFO     Stromal done!

# %% [markdown]
# Dump the paths to the bed and bw files for peak calling

# %%
import pickle

# Export the paths
pickle.dump(
    bed_paths,
    open(os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bed_files/bed_paths.pkl'), 'wb')
)
pickle.dump(
    bw_paths,
    open(os.path.join(work_dir, 'scATAC/consensus_peak_calling/pseudobulk_bw_files/bw_paths.pkl'), 'wb')
)

# %% [markdown]
# We can now run cell type specific peak calling using MACS2. pycisTopic has another useful function for this.

# %%
from pycisTopic.pseudobulk_peak_calling import peak_calling

# Run peak calling
macs_path='/cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2'
narrow_peaks_dict = peak_calling(
    macs_path,
    bed_paths,
    os.path.join(work_dir, 'scATAC/consensus_peak_calling/MACS/'),
    genome_size='hs',
    n_cpu=12,
    input_format='BEDPE',
    shift=73,
    ext_size=146,
    keep_dup = 'all',
    q_value = 0.05,
    _temp_dir = os.path.join(tmp_dir, 'ray_spill')
)
# Out:
# 2023-01-15 07:53:26,502	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2044428) 2023-01-15 07:53:39,567 cisTopic     INFO     Calling peaks for Stromal with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Stromal.bed.gz --name Stromal  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044425) 2023-01-15 07:53:39,594 cisTopic     INFO     Calling peaks for Skeletal_muscle with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Skeletal_muscle.bed.gz --name Skeletal_muscle  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044422) 2023-01-15 07:53:39,605 cisTopic     INFO     Calling peaks for Capsule with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Capsule.bed.gz --name Capsule  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044427) 2023-01-15 07:53:39,579 cisTopic     INFO     Calling peaks for Medulla with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Medulla.bed.gz --name Medulla  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044431) 2023-01-15 07:53:39,584 cisTopic     INFO     Calling peaks for Smooth_muscle with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Smooth_muscle.bed.gz --name Smooth_muscle  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044421) 2023-01-15 07:53:39,669 cisTopic     INFO     Calling peaks for Cortex with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Cortex.bed.gz --name Cortex  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044430) 2023-01-15 07:53:39,663 cisTopic     INFO     Calling peaks for Fibroblast with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Fibroblast.bed.gz --name Fibroblast  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044423) 2023-01-15 07:53:39,654 cisTopic     INFO     Calling peaks for Sox10_ with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Sox10_.bed.gz --name Sox10_  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044429) 2023-01-15 07:53:39,679 cisTopic     INFO     Calling peaks for Macrophages with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Macrophages.bed.gz --name Macrophages  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044426) 2023-01-15 07:53:39,811 cisTopic     INFO     Calling peaks for Endothelial with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Endothelial.bed.gz --name Endothelial  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044424) 2023-01-15 07:53:39,810 cisTopic     INFO     Calling peaks for Hepatocyte with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Hepatocyte.bed.gz --name Hepatocyte  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044420) 2023-01-15 07:53:39,829 cisTopic     INFO     Calling peaks for Adipocytes with /cellar/users/aklie/opt/miniconda3/envs/scenicplus/bin/macs2 callpeak --treatment mouse_adrenal/scATAC/consensus_peak_calling/pseudobulk_bed_files/Adipocytes.bed.gz --name Adipocytes  --outdir mouse_adrenal/scATAC/consensus_peak_calling/MACS/ --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2044425) 2023-01-15 07:53:46,810 cisTopic     INFO     Skeletal_muscle done!
# (macs_call_peak_ray pid=2044424) 2023-01-15 07:53:48,470 cisTopic     INFO     Hepatocyte done!
# (macs_call_peak_ray pid=2044431) 2023-01-15 07:54:02,094 cisTopic     INFO     Smooth_muscle done!
# (macs_call_peak_ray pid=2044422) 2023-01-15 07:54:02,862 cisTopic     INFO     Capsule done!
# (macs_call_peak_ray pid=2044423) 2023-01-15 07:54:33,188 cisTopic     INFO     Sox10_ done!
# (macs_call_peak_ray pid=2044429) 2023-01-15 07:55:16,270 cisTopic     INFO     Macrophages done!
# (macs_call_peak_ray pid=2044430) 2023-01-15 07:56:03,457 cisTopic     INFO     Fibroblast done!
# (macs_call_peak_ray pid=2044428) 2023-01-15 07:56:38,317 cisTopic     INFO     Stromal done!
# (macs_call_peak_ray pid=2044420) 2023-01-15 07:56:49,962 cisTopic     INFO     Adipocytes done!
# (macs_call_peak_ray pid=2044427) 2023-01-15 07:59:06,210 cisTopic     INFO     Medulla done!
# (macs_call_peak_ray pid=2044426) 2023-01-15 07:59:19,057 cisTopic     INFO     Endothelial done!
# (macs_call_peak_ray pid=2044421) 2023-01-15 08:22:11,520 cisTopic     INFO     Cortex done!

# %%
# Dump the return object to a pickle
pickle.dump(
    narrow_peaks_dict,
    open(os.path.join(work_dir, 'scATAC/consensus_peak_calling/MACS/narrow_peaks_dict.pkl'), 'wb')
)

# %% [markdown]
# In order to generate a region x cell matrix, we need a consensus peak set. There a lot of ways to do this, again, pycisTopic has a couple functions that we will take advantage of

# %%
from pycisTopic.iterative_peak_calling import get_consensus_peaks

# %%
from pycisTopic.iterative_peak_calling import *

# Get consensus peaks
peak_half_width = 250
path_to_blacklist= os.path.join(work_dir, 'hg38-blacklist.v2.bed')
consensus_peaks=get_consensus_peaks(
    narrow_peaks_dict, 
    peak_half_width, 
    chromsizes=chromsizes, 
    path_to_blacklist=path_to_blacklist
)
# Out:
# 2023-01-15 08:22:15,531 cisTopic     INFO     Extending and merging peaks per class
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2023-01-15 08:32:59,529 cisTopic     INFO     Done!

# %% [markdown]
# Save the consensus regions as a bed file. This will be used for multiple downstream steps

# %%
consensus_peaks.to_bed(
    path = os.path.join(work_dir, 'scATAC/consensus_peak_calling/consensus_regions.bed'),
    keep=True,
    compression='infer',
    chain=False
)

# %% [markdown]
# We can now perform QC on our scATAC data using the consensus peak set. We start by grabbing TSS annotations for protein coding genes. Again remember to choose the correct organism

# %%
import pybiomart as pbm

# Grab TSS annotations for mouse protein coding genes
dataset = pbm.Dataset(name='mmusculus_gene_ensembl',  host='http://www.ensembl.org')
annot = dataset.query(attributes=['chromosome_name', 'transcription_start_site', 'strand', 'external_gene_name', 'transcript_biotype'])
annot['Chromosome/scaffold name'] = annot['Chromosome/scaffold name'].to_numpy(dtype = str)
filter = annot['Chromosome/scaffold name'].str.contains('CHR|GL|JH|MT')
annot = annot[~filter]
annot['Chromosome/scaffold name'] = annot['Chromosome/scaffold name'].str.replace(r'(\b\S)', r'chr\1')
annot.columns=['Chromosome', 'Start', 'Strand', 'Gene', 'Transcript_type']
annot = annot[annot.Transcript_type == 'protein_coding']
# Out:
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pybiomart/dataset.py:269: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   result = pd.read_csv(StringIO(response.text), sep='\t')

# %%
# Each sample will have the same regions here as we want to merge
path_to_regions = dict.fromkeys(fragments_dict.keys(), os.path.join(work_dir, 'scATAC/consensus_peak_calling/consensus_regions.bed'))
path_to_regions
# Out:
# {'ENCFF187VMN': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF035SPT': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF622EUO': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF119IVK': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF683IBE': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF042ZJI': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF176LJV': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed',
#  'ENCFF101BLM': 'mouse_adrenal/scATAC/consensus_peak_calling/consensus_regions.bed'}

# %% [markdown]
# Next is to calculate a set of metrics for each cell based on consensus regions. Note that this requires counting fragments again

# %%
from pycisTopic.qc import *

# Calculate QC stats for each sample
metadata_bc, profile_data_dict = compute_qc_stats(
    fragments_dict = fragments_dict,
    tss_annotation = annot,
    stats=['barcode_rank_plot', 'duplicate_rate', 'insert_size_distribution', 'profile_tss', 'frip'],
    label_list = None,
    path_to_regions = path_to_regions,
    n_cpu = 1,
    valid_bc = None,
    n_frag = 100,
    n_bc = None,
    tss_flank_window = 1000,
    tss_window = 50,
    tss_minimum_signal_window = 100,
    tss_rolling_window = 10,
    remove_duplicates = True,
    _temp_dir = os.path.join(tmp_dir + 'ray_spill')
)

# Dump the qc results in some objects
if not os.path.exists(os.path.join(work_dir, 'scATAC/quality_control')):
    os.makedirs(os.path.join(work_dir, 'scATAC/quality_control'))

pickle.dump(metadata_bc,
            open(os.path.join(work_dir, 'scATAC/quality_control/metadata_bc.pkl'), 'wb'))

pickle.dump(profile_data_dict,
            open(os.path.join(work_dir, 'scATAC/quality_control/profile_data_dict.pkl'), 'wb'))
# Out:
# 2023-01-15 09:05:14,033 cisTopic     INFO     Reading ENCFF187VMN
# 2023-01-15 09:06:44,590 cisTopic     INFO     Computing barcode rank plot for ENCFF187VMN
# 2023-01-15 09:06:44,591 cisTopic     INFO     Counting fragments
# 2023-01-15 09:06:50,918 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:06:50,969 cisTopic     INFO     Returning plot data
# 2023-01-15 09:06:50,973 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:06:57,171 cisTopic     INFO     Computing duplicate rate plot for ENCFF187VMN
# 2023-01-15 09:07:05,086 cisTopic     INFO     Return plot data
# 2023-01-15 09:07:05,317 cisTopic     INFO     Computing insert size distribution for ENCFF187VMN
# 2023-01-15 09:07:05,319 cisTopic     INFO     Counting fragments
# 2023-01-15 09:07:06,860 cisTopic     INFO     Returning plot data
# 2023-01-15 09:07:56,480 cisTopic     INFO     Computing TSS profile for ENCFF187VMN
# 2023-01-15 09:08:05,050 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:08:05,102 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:08:33,378 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:08:49,005 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:09:00,903 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:09:01,069 cisTopic     INFO     Computing FRIP profile for ENCFF187VMN
# 2023-01-15 09:09:03,023 cisTopic     INFO     Counting fragments
# 2023-01-15 09:09:14,962 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:10:01,726 cisTopic     INFO     Sample ENCFF187VMN done!
# 2023-01-15 09:10:01,728 cisTopic     INFO     Reading ENCFF035SPT
# 2023-01-15 09:11:28,004 cisTopic     INFO     Computing barcode rank plot for ENCFF035SPT
# 2023-01-15 09:11:28,006 cisTopic     INFO     Counting fragments
# 2023-01-15 09:11:33,313 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:11:33,357 cisTopic     INFO     Returning plot data
# 2023-01-15 09:11:33,360 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:11:37,878 cisTopic     INFO     Computing duplicate rate plot for ENCFF035SPT
# 2023-01-15 09:11:45,163 cisTopic     INFO     Return plot data
# 2023-01-15 09:11:45,338 cisTopic     INFO     Computing insert size distribution for ENCFF035SPT
# 2023-01-15 09:11:45,340 cisTopic     INFO     Counting fragments
# 2023-01-15 09:11:46,897 cisTopic     INFO     Returning plot data
# 2023-01-15 09:12:36,025 cisTopic     INFO     Computing TSS profile for ENCFF035SPT
# 2023-01-15 09:12:45,411 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:12:45,459 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:13:13,605 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:13:24,395 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:13:32,375 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:13:32,542 cisTopic     INFO     Computing FRIP profile for ENCFF035SPT
# 2023-01-15 09:13:34,496 cisTopic     INFO     Counting fragments
# 2023-01-15 09:13:44,129 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:14:25,542 cisTopic     INFO     Sample ENCFF035SPT done!
# 2023-01-15 09:14:25,543 cisTopic     INFO     Reading ENCFF622EUO
# 2023-01-15 09:16:05,951 cisTopic     INFO     Computing barcode rank plot for ENCFF622EUO
# 2023-01-15 09:16:05,953 cisTopic     INFO     Counting fragments
# 2023-01-15 09:16:11,914 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:16:11,960 cisTopic     INFO     Returning plot data
# 2023-01-15 09:16:11,964 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:16:18,361 cisTopic     INFO     Computing duplicate rate plot for ENCFF622EUO
# 2023-01-15 09:16:26,781 cisTopic     INFO     Return plot data
# 2023-01-15 09:16:27,011 cisTopic     INFO     Computing insert size distribution for ENCFF622EUO
# 2023-01-15 09:16:27,013 cisTopic     INFO     Counting fragments
# 2023-01-15 09:16:28,821 cisTopic     INFO     Returning plot data
# 2023-01-15 09:17:28,724 cisTopic     INFO     Computing TSS profile for ENCFF622EUO
# 2023-01-15 09:17:39,992 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:17:40,042 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:18:13,394 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:18:21,141 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:18:26,911 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:18:27,078 cisTopic     INFO     Computing FRIP profile for ENCFF622EUO
# 2023-01-15 09:18:29,009 cisTopic     INFO     Counting fragments
# 2023-01-15 09:18:43,220 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:19:36,984 cisTopic     INFO     Sample ENCFF622EUO done!
# 2023-01-15 09:19:36,985 cisTopic     INFO     Reading ENCFF119IVK
# 2023-01-15 09:20:59,989 cisTopic     INFO     Computing barcode rank plot for ENCFF119IVK
# 2023-01-15 09:20:59,991 cisTopic     INFO     Counting fragments
# 2023-01-15 09:21:04,929 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:21:04,981 cisTopic     INFO     Returning plot data
# 2023-01-15 09:21:04,983 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:21:09,956 cisTopic     INFO     Computing duplicate rate plot for ENCFF119IVK
# 2023-01-15 09:21:17,068 cisTopic     INFO     Return plot data
# 2023-01-15 09:21:17,248 cisTopic     INFO     Computing insert size distribution for ENCFF119IVK
# 2023-01-15 09:21:17,249 cisTopic     INFO     Counting fragments
# 2023-01-15 09:21:18,703 cisTopic     INFO     Returning plot data
# 2023-01-15 09:22:03,678 cisTopic     INFO     Computing TSS profile for ENCFF119IVK
# 2023-01-15 09:22:12,131 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:22:12,181 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:22:37,775 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:22:44,568 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:22:49,660 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:22:49,848 cisTopic     INFO     Computing FRIP profile for ENCFF119IVK
# 2023-01-15 09:22:51,839 cisTopic     INFO     Counting fragments
# 2023-01-15 09:23:01,615 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:23:40,594 cisTopic     INFO     Sample ENCFF119IVK done!
# 2023-01-15 09:23:40,595 cisTopic     INFO     Reading ENCFF683IBE
# 2023-01-15 09:25:19,235 cisTopic     INFO     Computing barcode rank plot for ENCFF683IBE
# 2023-01-15 09:25:19,238 cisTopic     INFO     Counting fragments
# 2023-01-15 09:25:26,746 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:25:26,801 cisTopic     INFO     Returning plot data
# 2023-01-15 09:25:26,803 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:25:33,842 cisTopic     INFO     Computing duplicate rate plot for ENCFF683IBE
# 2023-01-15 09:25:43,222 cisTopic     INFO     Return plot data
# 2023-01-15 09:25:43,395 cisTopic     INFO     Computing insert size distribution for ENCFF683IBE
# 2023-01-15 09:25:43,396 cisTopic     INFO     Counting fragments
# 2023-01-15 09:25:45,320 cisTopic     INFO     Returning plot data
# 2023-01-15 09:26:41,466 cisTopic     INFO     Computing TSS profile for ENCFF683IBE
# 2023-01-15 09:26:51,919 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:26:51,966 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:27:23,943 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:27:33,586 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:27:41,007 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:27:41,171 cisTopic     INFO     Computing FRIP profile for ENCFF683IBE
# 2023-01-15 09:27:43,106 cisTopic     INFO     Counting fragments
# 2023-01-15 09:27:55,072 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:28:43,158 cisTopic     INFO     Sample ENCFF683IBE done!
# 2023-01-15 09:28:43,159 cisTopic     INFO     Reading ENCFF042ZJI
# 2023-01-15 09:30:16,005 cisTopic     INFO     Computing barcode rank plot for ENCFF042ZJI
# 2023-01-15 09:30:16,007 cisTopic     INFO     Counting fragments
# 2023-01-15 09:30:21,904 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:30:21,949 cisTopic     INFO     Returning plot data
# 2023-01-15 09:30:21,952 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:30:27,870 cisTopic     INFO     Computing duplicate rate plot for ENCFF042ZJI
# 2023-01-15 09:30:35,614 cisTopic     INFO     Return plot data
# 2023-01-15 09:30:35,819 cisTopic     INFO     Computing insert size distribution for ENCFF042ZJI
# 2023-01-15 09:30:35,820 cisTopic     INFO     Counting fragments
# 2023-01-15 09:30:37,471 cisTopic     INFO     Returning plot data
# 2023-01-15 09:31:32,499 cisTopic     INFO     Computing TSS profile for ENCFF042ZJI
# 2023-01-15 09:31:41,788 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:31:41,838 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:32:10,550 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:32:17,043 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:32:22,020 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:32:22,187 cisTopic     INFO     Computing FRIP profile for ENCFF042ZJI
# 2023-01-15 09:32:24,088 cisTopic     INFO     Counting fragments
# 2023-01-15 09:32:35,391 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:33:19,562 cisTopic     INFO     Sample ENCFF042ZJI done!
# 2023-01-15 09:33:19,563 cisTopic     INFO     Reading ENCFF176LJV
# 2023-01-15 09:35:00,017 cisTopic     INFO     Computing barcode rank plot for ENCFF176LJV
# 2023-01-15 09:35:00,019 cisTopic     INFO     Counting fragments
# 2023-01-15 09:35:06,992 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:35:07,039 cisTopic     INFO     Returning plot data
# 2023-01-15 09:35:07,042 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:35:14,203 cisTopic     INFO     Computing duplicate rate plot for ENCFF176LJV
# 2023-01-15 09:35:23,709 cisTopic     INFO     Return plot data
# 2023-01-15 09:35:23,921 cisTopic     INFO     Computing insert size distribution for ENCFF176LJV
# 2023-01-15 09:35:23,922 cisTopic     INFO     Counting fragments
# 2023-01-15 09:35:25,688 cisTopic     INFO     Returning plot data
# 2023-01-15 09:36:24,368 cisTopic     INFO     Computing TSS profile for ENCFF176LJV
# 2023-01-15 09:36:34,532 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:36:34,581 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:37:06,852 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:37:15,342 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:37:21,946 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:37:22,113 cisTopic     INFO     Computing FRIP profile for ENCFF176LJV
# 2023-01-15 09:37:24,099 cisTopic     INFO     Counting fragments
# 2023-01-15 09:37:37,612 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:38:26,477 cisTopic     INFO     Sample ENCFF176LJV done!
# 2023-01-15 09:38:26,478 cisTopic     INFO     Reading ENCFF101BLM
# 2023-01-15 09:39:56,674 cisTopic     INFO     Computing barcode rank plot for ENCFF101BLM
# 2023-01-15 09:39:56,676 cisTopic     INFO     Counting fragments
# 2023-01-15 09:40:02,766 cisTopic     INFO     Marking barcodes with more than 100
# 2023-01-15 09:40:02,819 cisTopic     INFO     Returning plot data
# 2023-01-15 09:40:02,821 cisTopic     INFO     Returning valid barcodes
# 2023-01-15 09:40:08,791 cisTopic     INFO     Computing duplicate rate plot for ENCFF101BLM
# 2023-01-15 09:40:16,714 cisTopic     INFO     Return plot data
# 2023-01-15 09:40:16,898 cisTopic     INFO     Computing insert size distribution for ENCFF101BLM
# 2023-01-15 09:40:16,899 cisTopic     INFO     Counting fragments
# 2023-01-15 09:40:18,473 cisTopic     INFO     Returning plot data
# 2023-01-15 09:41:10,246 cisTopic     INFO     Computing TSS profile for ENCFF101BLM
# 2023-01-15 09:41:19,734 cisTopic     INFO     Formatting annnotation
# 2023-01-15 09:41:19,782 cisTopic     INFO     Creating coverage matrix
# 2023-01-15 09:41:48,990 cisTopic     INFO     Coverage matrix done
# 2023-01-15 09:41:57,548 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# 2023-01-15 09:42:04,150 cisTopic     INFO     Returning normalized sample TSS enrichment data
# 2023-01-15 09:42:04,316 cisTopic     INFO     Computing FRIP profile for ENCFF101BLM
# 2023-01-15 09:42:06,259 cisTopic     INFO     Counting fragments
# 2023-01-15 09:42:17,425 cisTopic     INFO     Intersecting fragments with regions
# 2023-01-15 09:43:01,085 cisTopic     INFO     Sample ENCFF101BLM done!

# %% [markdown]
# We can plot a few QC plots and see how filtering would affect the cells called

# %%
from pycisTopic.qc import *

# Perform some filtering to keep only high quality cells
QC_filters = {
    'Log_unique_nr_frag': [2 , None],
    'FRIP':               [0.3, None],
    'TSS_enrichment':     [1   , None],
    'Dupl_rate':          [None, None]

}
bc_passing_filters = {}
for sample in fragments_dict:
    print("Sample", sample)
    FRIP_NR_FRAG_filter = plot_barcode_metrics(
        metadata_bc[sample],
        var_x='Log_unique_nr_frag',
        var_y='FRIP',
        min_x=QC_filters['Log_unique_nr_frag'][0],
        max_x=QC_filters['Log_unique_nr_frag'][1],
        min_y=QC_filters['FRIP'][0],
        max_y=QC_filters['FRIP'][1],
        return_cells=True,
        return_fig=False,
        plot=False
    )
    # Return figure to plot together with other metrics, and cells passing filters
    TSS_NR_FRAG_filter = plot_barcode_metrics(
        metadata_bc[sample],
        var_x='Log_unique_nr_frag',
        var_y='TSS_enrichment',
        min_x=QC_filters['Log_unique_nr_frag'][0],
        max_x=QC_filters['Log_unique_nr_frag'][1],
        min_y=QC_filters['TSS_enrichment'][0],
        max_y=QC_filters['TSS_enrichment'][1],
        return_cells=True,
        return_fig=False,
        plot=False
    )
    bc_passing_filters[sample] = list((set(FRIP_NR_FRAG_filter) & set(TSS_NR_FRAG_filter)))
# Out:
# Sample ENCFF187VMN
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF035SPT
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF622EUO
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF119IVK
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF683IBE
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF042ZJI
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF176LJV
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# Sample ENCFF101BLM
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1871: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# /cellar/users/aklie/opt/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/qc.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(

# %%
# Dump and print the cells that passed!
pickle.dump(
    bc_passing_filters,
    open(os.path.join(work_dir, 'scATAC/quality_control/bc_passing_filters.pkl'), 'wb')
)
for sample in bc_passing_filters:
    print(f"{len(bc_passing_filters[sample])} barcodes passed QC stats for {sample}")
# Out:
# 3887 barcodes passed QC stats for ENCFF187VMN
# 5623 barcodes passed QC stats for ENCFF035SPT
# 5210 barcodes passed QC stats for ENCFF622EUO
# 4669 barcodes passed QC stats for ENCFF119IVK
# 6547 barcodes passed QC stats for ENCFF683IBE
# 4875 barcodes passed QC stats for ENCFF042ZJI
# 6208 barcodes passed QC stats for ENCFF176LJV
# 5236 barcodes passed QC stats for ENCFF101BLM
