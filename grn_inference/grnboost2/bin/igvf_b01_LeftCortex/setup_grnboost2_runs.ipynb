# %% [markdown]
# # TODO

# %% [markdown]
# # Set-up

# %%
import os
import sys
import random
import time
import pandas as pd
import numpy as np

# ignore pandas warnings
import warnings
warnings.filterwarnings("ignore")

# %%
os.chdir("/cellar/users/aklie/projects/igvf/topic_grn_links/grn_inference/grnboost2/bin/igvf_b01_LeftCortex")
os.getcwd()
# Out:
# '/cellar/users/aklie/projects/igvf/topic_grn_links/grn_inference/grnboost2/bin/igvf_b01_LeftCortex'

# %% [markdown]
# # Load file metadata

# %%
# Where the input metadata is stored for all files to run on
in_dir = "/cellar/users/aklie/data/igvf/topic_grn_links/subsets/for_regulon_inference/igvf_b01_LeftCortex/31Aug23/3744376661_20230829-175127"

# %%
# Load the file metadata
file_metadata = pd.read_csv(os.path.join(in_dir, "file_metadata.tsv"), sep="\t")
file_metadata.head()
# Out:
#                                       file file_type       cells        genes  \
# 0          random_500.random_2000.raw.h5ad     .h5ad  random_500  random_2000
# 1          random_500.random_2000.raw.loom     .loom  random_500  random_2000
# 2           random_500.random_2000.raw.tsv      .tsv  random_500  random_2000
# 3  random_500.random_2000.log1p_cp10k.h5ad     .h5ad  random_500  random_2000
# 4  random_500.random_2000.log1p_cp10k.loom     .loom  random_500  random_2000
#
#   normalization  n_cells  n_genes  percent_int  percent_0  percent_less_than_0
# 0           raw      500     2000     1.000000   0.937368                  0.0
# 1           raw      500     2000     1.000000   0.937368                  0.0
# 2           raw     2000      500     1.000000   0.937368                  0.0
# 3   log1p_cp10k      500     2000     0.937368   0.937368                  0.0
# 4   log1p_cp10k      500     2000     0.937368   0.937368                  0.0

# %% [markdown]
# # Extract runs of interest

# %%
# Parameters for runs of interest
genes = ["0.05"]  # could be ["0.01", "0.05", "0.1", "0.2"]
cells = ["balanced_genotype_microglia"]
normalizations = ["raw", "log1p_cp10k", "pf_log1p_pf", "cpm_rank"]
file_types = [".loom"]  # could be [".h5ad", ".loom", ".tsv"], but selecting tsv for GENIE3
out_dir = "/cellar/users/aklie/projects/igvf/topic_grn_links/grn_inference/grnboost2/results/igvf_b01_LeftCortex"

# %%
# Set up masks for the file metadata based on above
genes_mask = file_metadata["genes"].isin(genes)
cells_mask = file_metadata["cells"].isin(cells)
normalizations_mask = file_metadata["normalization"].isin(normalizations)
file_types_mask = file_metadata["file_type"].isin(file_types)

# %%
# Extract the files to run
curr_metadata = file_metadata[genes_mask & cells_mask & normalizations_mask & file_types_mask]
curr_metadata["in_file"] = curr_metadata["cells"] + "/" + curr_metadata["genes"].astype(str) + "/" + curr_metadata["normalization"] + "/" + curr_metadata["file"]
curr_metadata["in_file_path"] = curr_metadata["in_file"].apply(lambda x: os.path.join(in_dir, x))
curr_metadata["genotype"] = [i.split(".")[0].split('-')[-1] for i in curr_metadata["file"]] 
curr_metadata["out_dir"] = out_dir
curr_metadata["out_dir_path"] = curr_metadata["out_dir"] + "/" + curr_metadata["cells"] + "/" + curr_metadata["genes"].astype(str) + "/" + curr_metadata["normalization"] + "/" + curr_metadata["genotype"]
curr_metadata
# Out:
#                                                   file file_type  \
# 483      balanced_genotype_microglia-B6J.0.05.raw.loom     .loom
# 484    balanced_genotype_microglia-CASTJ.0.05.raw.loom     .loom
# 485     balanced_genotype_microglia-both.0.05.raw.loom     .loom
# 492  balanced_genotype_microglia-B6J.0.05.log1p_cp1...     .loom
# 493  balanced_genotype_microglia-CASTJ.0.05.log1p_c...     .loom
# 494  balanced_genotype_microglia-both.0.05.log1p_cp...     .loom
# 501  balanced_genotype_microglia-B6J.0.05.pf_log1p_...     .loom
# 502  balanced_genotype_microglia-CASTJ.0.05.pf_log1...     .loom
# 503  balanced_genotype_microglia-both.0.05.pf_log1p...     .loom
# 510  balanced_genotype_microglia-B6J.0.05.cpm_rank....     .loom
# 511  balanced_genotype_microglia-CASTJ.0.05.cpm_ran...     .loom
# 512  balanced_genotype_microglia-both.0.05.cpm_rank...     .loom
#
#                            cells genes normalization  n_cells  n_genes  \
# 483  balanced_genotype_microglia  0.05           raw     1206     4077
# 484  balanced_genotype_microglia  0.05           raw     1206     4077
# 485  balanced_genotype_microglia  0.05           raw     2412     4077
# 492  balanced_genotype_microglia  0.05   log1p_cp10k     1206     4077
# 493  balanced_genotype_microglia  0.05   log1p_cp10k     1206     4077
# 494  balanced_genotype_microglia  0.05   log1p_cp10k     2412     4077
# 501  balanced_genotype_microglia  0.05   pf_log1p_pf     1206     4077
# 502  balanced_genotype_microglia  0.05   pf_log1p_pf     1206     4077
# 503  balanced_genotype_microglia  0.05   pf_log1p_pf     2412     4077
# 510  balanced_genotype_microglia  0.05      cpm_rank     1206     4077
# 511  balanced_genotype_microglia  0.05      cpm_rank     1206     4077
# 512  balanced_genotype_microglia  0.05      cpm_rank     2412     4077
#
#      percent_int  percent_0  percent_less_than_0  \
# 483     1.000000   0.840221             0.000000
# 484     1.000000   0.842789             0.000000
# 485     1.000000   0.841505             0.000000
# 492     0.840221   0.840221             0.000000
# 493     0.842789   0.842789             0.000000
# 494     0.841505   0.841505             0.000000
# 501     0.840221   0.840221             0.000000
# 502     0.842789   0.842789             0.000000
# 503     0.841505   0.841505             0.000000
# 510     0.013455   0.002903             0.498555
# 511     0.013693   0.002988             0.498517
# 512     0.013574   0.002945             0.498536
#
#                                                in_file  \
# 483  balanced_genotype_microglia/0.05/raw/balanced_...
# 484  balanced_genotype_microglia/0.05/raw/balanced_...
# 485  balanced_genotype_microglia/0.05/raw/balanced_...
# 492  balanced_genotype_microglia/0.05/log1p_cp10k/b...
# 493  balanced_genotype_microglia/0.05/log1p_cp10k/b...
# 494  balanced_genotype_microglia/0.05/log1p_cp10k/b...
# 501  balanced_genotype_microglia/0.05/pf_log1p_pf/b...
# 502  balanced_genotype_microglia/0.05/pf_log1p_pf/b...
# 503  balanced_genotype_microglia/0.05/pf_log1p_pf/b...
# 510  balanced_genotype_microglia/0.05/cpm_rank/bala...
# 511  balanced_genotype_microglia/0.05/cpm_rank/bala...
# 512  balanced_genotype_microglia/0.05/cpm_rank/bala...
#
#                                           in_file_path genotype  \
# 483  /cellar/users/aklie/data/igvf/topic_grn_links/...      B6J
# 484  /cellar/users/aklie/data/igvf/topic_grn_links/...    CASTJ
# 485  /cellar/users/aklie/data/igvf/topic_grn_links/...     both
# 492  /cellar/users/aklie/data/igvf/topic_grn_links/...      B6J
# 493  /cellar/users/aklie/data/igvf/topic_grn_links/...    CASTJ
# 494  /cellar/users/aklie/data/igvf/topic_grn_links/...     both
# 501  /cellar/users/aklie/data/igvf/topic_grn_links/...      B6J
# 502  /cellar/users/aklie/data/igvf/topic_grn_links/...    CASTJ
# 503  /cellar/users/aklie/data/igvf/topic_grn_links/...     both
# 510  /cellar/users/aklie/data/igvf/topic_grn_links/...      B6J
# 511  /cellar/users/aklie/data/igvf/topic_grn_links/...    CASTJ
# 512  /cellar/users/aklie/data/igvf/topic_grn_links/...     both
#
#                                                out_dir  \
# 483  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 484  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 485  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 492  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 493  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 494  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 501  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 502  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 503  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 510  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 511  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 512  /cellar/users/aklie/projects/igvf/topic_grn_li...
#
#                                           out_dir_path
# 483  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 484  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 485  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 492  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 493  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 494  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 501  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 502  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 503  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 510  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 511  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 512  /cellar/users/aklie/projects/igvf/topic_grn_li...

# %%
time_id = time.strftime("%Y%m%d-%H%M%S")
run_id =  random.getrandbits(32)
run = str(run_id) + "_" + time_id

# %%
curr_run = curr_metadata[["in_file_path", "out_dir_path"]]
curr_run["tf_list"] = "/cellar/users/aklie/opt/igvf-ucsd/grnboost2_pipeline/data/tf_lists/allTFs_mm.txt"
curr_run["num_runs"] = 5
curr_run["run_id"] = run
curr_run.to_csv(f"{run}_paths.csv", index=False)

# %% [markdown]
# # DONE

# %% [markdown]
# ---
