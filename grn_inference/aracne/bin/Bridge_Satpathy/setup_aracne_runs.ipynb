# %% [markdown]
# # TODO

# %% [markdown]
# # Set-up

# %%
import os
import sys
import random
import time
import pandas as pd
import numpy as np

# ignore pandas warnings
import warnings
warnings.filterwarnings("ignore")

# %%
os.chdir("/cellar/users/aklie/projects/igvf/topic_grn_links/grn_inference/aracne/bin/Bridge_Satpathy")
os.getcwd()
# Out:
# '/cellar/users/aklie/projects/igvf/topic_grn_links/grn_inference/aracne/bin/Bridge_Satpathy'

# %% [markdown]
# # Load file metadata

# %%
# Where the input metadata is stored for all files to run on
in_dir = "/cellar/users/aklie/data/igvf/topic_grn_links/subsets/for_regulon_inference/Bridge_Satpathy/29Aug23/3744376661_20230829-175127"

# %%
# Load the file metadata
file_metadata = pd.read_csv(os.path.join(in_dir, "file_metadata.tsv"), sep="\t")
file_metadata.head()
# Out:
#                                       file file_type       cells        genes  \
# 0          random_500.random_2000.raw.h5ad     .h5ad  random_500  random_2000
# 1          random_500.random_2000.raw.loom     .loom  random_500  random_2000
# 2           random_500.random_2000.raw.tsv      .tsv  random_500  random_2000
# 3  random_500.random_2000.log1p_cp10k.h5ad     .h5ad  random_500  random_2000
# 4  random_500.random_2000.log1p_cp10k.loom     .loom  random_500  random_2000
#
#   normalization  n_cells  n_genes  percent_int  percent_0  percent_less_than_0
# 0           raw      500     2000     0.995209   0.951713                  0.0
# 1           raw      500     2000     0.995209   0.951713                  0.0
# 2           raw     2000      500     0.995209   0.951713                  0.0
# 3   log1p_cp10k      500     2000     0.951713   0.951713                  0.0
# 4   log1p_cp10k      500     2000     0.951713   0.951713                  0.0

# %% [markdown]
# # Extract runs of interest

# %%
# Parameters for runs of interest
genes = ["0.05"] # could be ["0.01", "0.05", "0.1", "0.2"]
cells = ["balanced_genotype_microglia"]
normalizations = ["raw", "pf_log1p_pf"]  # could be ["raw", "log1p_cp10k", "pf_log1p_pf", "cpm_rank"]
file_types = [".tsv"]  # could be [".h5ad", ".loom", ".tsv"], but selecting tsv for ARACNe
out_dir = "/cellar/users/aklie/projects/igvf/topic_grn_links/grn_inference/aracne/results/Bridge_Satpathy"

# %%
# Set up masks for the file metadata based on above
genes_mask = file_metadata["genes"].isin(genes)
cells_mask = file_metadata["cells"].isin(cells)
normalizations_mask = file_metadata["normalization"].isin(normalizations)
file_types_mask = file_metadata["file_type"].isin(file_types)

# %%
# Extract the files to run
curr_metadata = file_metadata[genes_mask & cells_mask & normalizations_mask & file_types_mask]
curr_metadata["in_file"] = curr_metadata["cells"] + "/" + curr_metadata["genes"].astype(str) + "/" + curr_metadata["normalization"] + "/" + curr_metadata["file"]
curr_metadata["in_file_path"] = curr_metadata["in_file"].apply(lambda x: os.path.join(in_dir, x))
curr_metadata["genotype"] = [i.split(".")[0].split('-')[-1] for i in curr_metadata["file"]] 
curr_metadata["out_dir"] = curr_metadata["cells"] + "/" + curr_metadata["genes"].astype(str) + "/" + curr_metadata["normalization"] + "/" + curr_metadata["genotype"]
curr_metadata["out_dir_path"] = curr_metadata["out_dir"].apply(lambda x: os.path.join(out_dir, x))
curr_metadata
# Out:
#                                                   file file_type  \
# 486       balanced_genotype_microglia-B6J.0.05.raw.tsv      .tsv
# 487     balanced_genotype_microglia-CASTJ.0.05.raw.tsv      .tsv
# 488      balanced_genotype_microglia-both.0.05.raw.tsv      .tsv
# 504  balanced_genotype_microglia-B6J.0.05.pf_log1p_...      .tsv
# 505  balanced_genotype_microglia-CASTJ.0.05.pf_log1...      .tsv
# 506  balanced_genotype_microglia-both.0.05.pf_log1p...      .tsv
#
#                            cells genes normalization  n_cells  n_genes  \
# 486  balanced_genotype_microglia  0.05           raw     6277     1498
# 487  balanced_genotype_microglia  0.05           raw     6277     1498
# 488  balanced_genotype_microglia  0.05           raw     6277     2996
# 504  balanced_genotype_microglia  0.05   pf_log1p_pf     6277     1498
# 505  balanced_genotype_microglia  0.05   pf_log1p_pf     6277     1498
# 506  balanced_genotype_microglia  0.05   pf_log1p_pf     6277     2996
#
#      percent_int  percent_0  percent_less_than_0  \
# 486     0.987272   0.873955                  0.0
# 487     0.982353   0.853771                  0.0
# 488     0.984812   0.863863                  0.0
# 504     0.873955   0.873955                  0.0
# 505     0.853771   0.853771                  0.0
# 506     0.863863   0.863863                  0.0
#
#                                                in_file  \
# 486  balanced_genotype_microglia/0.05/raw/balanced_...
# 487  balanced_genotype_microglia/0.05/raw/balanced_...
# 488  balanced_genotype_microglia/0.05/raw/balanced_...
# 504  balanced_genotype_microglia/0.05/pf_log1p_pf/b...
# 505  balanced_genotype_microglia/0.05/pf_log1p_pf/b...
# 506  balanced_genotype_microglia/0.05/pf_log1p_pf/b...
#
#                                           in_file_path genotype  \
# 486  /cellar/users/aklie/data/igvf/topic_grn_links/...      B6J
# 487  /cellar/users/aklie/data/igvf/topic_grn_links/...    CASTJ
# 488  /cellar/users/aklie/data/igvf/topic_grn_links/...     both
# 504  /cellar/users/aklie/data/igvf/topic_grn_links/...      B6J
# 505  /cellar/users/aklie/data/igvf/topic_grn_links/...    CASTJ
# 506  /cellar/users/aklie/data/igvf/topic_grn_links/...     both
#
#                                                out_dir  \
# 486           balanced_genotype_microglia/0.05/raw/B6J
# 487         balanced_genotype_microglia/0.05/raw/CASTJ
# 488          balanced_genotype_microglia/0.05/raw/both
# 504   balanced_genotype_microglia/0.05/pf_log1p_pf/B6J
# 505  balanced_genotype_microglia/0.05/pf_log1p_pf/C...
# 506  balanced_genotype_microglia/0.05/pf_log1p_pf/both
#
#                                           out_dir_path
# 486  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 487  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 488  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 504  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 505  /cellar/users/aklie/projects/igvf/topic_grn_li...
# 506  /cellar/users/aklie/projects/igvf/topic_grn_li...

# %%
time_id = time.strftime("%Y%m%d-%H%M%S")
run_id =  random.getrandbits(32)
run = str(run_id) + "_" + time_id

# %%
curr_run = curr_metadata[["in_file_path", "out_dir_path"]]
curr_run["tf_list"] = "/cellar/users/aklie/opt/igvf-ucsd/aracne_pipeline/data/tf_cotf_signalling_list/mouse/tf_mus_symbol.txt"
curr_run["pval"] = "1e-8"
curr_run["num_boostraps"] = 5
curr_run["tf_type"] = "tf"
curr_run["out_dir_path"] = curr_run["out_dir_path"] +  "/" + curr_run["tf_type"]
curr_run["run_id"] = run
curr_run.to_csv(f"{run}_paths.csv", index=False)

# %% [markdown]
# # DONE

# %% [markdown]
# ---
